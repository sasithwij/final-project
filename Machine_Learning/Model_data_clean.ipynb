# %%
from sklearn import tree
import pandas as pd
import os
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
spotifydf = pd.read_csv('2020only_Clean_Spotify_Attribute_Data.csv')
spotifydf = spotifydf.rename(columns={"duration_ms": "duration_s"})

# %%
spotifydf["popularity"].describe()
# Out:
# count    4294.000000
# mean       24.064741
# std        30.118641
# min         0.000000
# 25%         0.000000
# 50%        10.000000
# 75%        41.000000
# max        96.000000
# Name: popularity, dtype: float64

# %%
spotifydf[spotifydf["popularity"] >   80]
# Out:
#                               name              artist  year  acousticness  \
# 156         Mood (feat. iann dior)          '24kGoldn'  2020        0.2210
# 158                      Good Days               'SZA'  2020        0.4990
# 160                      positions     'Ariana Grande'  2020        0.4680
# 162                          34+35     'Ariana Grande'  2020        0.2370
# 164                        Whoopty                'CJ'  2020        0.1900
# ...                            ...                 ...   ...           ...
# 3651                          Nada  'Cali Y El Dandee'  2020        0.0518
# 3671                       Secrets            'Regard'  2020        0.0412
# 3696  Some Say - Felix Jaehn Remix               'Nea'  2020        0.4060
# 3769                    Travesuras     'Flow La Movie'  2020        0.1820
# 4081    Madrid (feat. Myke Towers)            'Maluma'  2020        0.2390
#
# ...

# %%
spotifydf.drop(columns=['name', 'artist', 'year', 'artists+name'], inplace=True)

# %%
spotifydf['popularity_over75']=1*(spotifydf['popularity']>=75)

# %%
spotifydf.drop(columns=['popularity'], inplace=True)

# %%
spotifydf.to_csv(r'C:\Users\sasit\OneDrive\Desktop\Data_Coursework\Project\final-project\Machine_Learning\Model_Data.csv', index = None, header=True)
