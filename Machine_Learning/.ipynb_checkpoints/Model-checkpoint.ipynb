# %%
from sklearn import tree
import pandas as pd
import os
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sn

# %%
spotifydf = pd.read_csv('Model_Data.csv')
spotifydf
# Out:
#       acousticness  danceability  duration_s  energy  explicit  \
# 0          0.88100         0.644     313.093   0.212         0
# 1          0.95500         0.627     295.093   0.184         0
# 2          0.88800         0.581     183.440   0.331         0
# 3          0.93000         0.442     147.907   0.399         0
# 4          0.94900         0.570      64.173   0.176         0
# ...            ...           ...         ...     ...       ...
# 4289       0.04840         0.693     177.148   0.826         0
# 4290       0.14100         0.544     215.014   0.407         1
# 4291       0.00917         0.792     147.615   0.866         0
# 4292       0.80600         0.671     218.147   0.589         0
# 4293       0.23900         0.677     197.710   0.460         0
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.000022   11    0.7980   -14.118     1       0.0347  117.072
# 1             0.000162    1    0.0986   -15.533     1       0.0450  115.864
# 2             0.000015    6    0.1470   -14.087     1       0.2430   88.303
# 3             0.000499    6    0.9120   -12.661     1       0.0780  121.662
# 4             0.000000    6    0.1470   -22.676     0       0.2990  135.687
# ...                ...  ...       ...       ...   ...          ...      ...
# 4289          0.000012    1    0.2310    -2.669     1       0.0762  126.049
# 4290          0.000000    4    0.2530   -12.745     0       0.2330  129.750
# 4291          0.000060    6    0.1780    -5.089     0       0.0356  125.972
# 4292          0.920000    4    0.1130   -12.393     0       0.0282  108.058
# 4293          0.891000    7    0.2150   -12.237     1       0.0258  112.208
#
#       valence  popularity_over75
# 0       0.441                  0
# 1       0.299                  0
# 2       0.642                  0
# 3       0.554                  0
# 4       0.348                  0
# ...       ...                ...
# 4289    0.361                  0
# 4290    0.490                  0
# 4291    0.186                  0
# 4292    0.714                  0
# 4293    0.747                  0
#
# [4294 rows x 14 columns]

# %%
spotifydf[spotifydf["popularity_over75"] == 1]
# Out:
#       acousticness  danceability  duration_s  energy  explicit  \
# 156        0.22100         0.700     140.526   0.722         1
# 158        0.49900         0.436     279.204   0.655         1
# 160        0.46800         0.737     172.325   0.802         1
# 162        0.23700         0.830     173.711   0.585         1
# 164        0.19000         0.711     123.429   0.598         1
# ...            ...           ...         ...     ...       ...
# 4166       0.40700         0.626     179.746   0.503         0
# 4168       0.15700         0.820     189.287   0.842         0
# 4186       0.00795         0.809     191.242   0.911         0
# 4200       0.24300         0.795     171.375   0.480         0
# 4223       0.02050         0.749     197.573   0.820         0
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 156           0.000000    7    0.2720    -3.558     0       0.0369   90.989
# 158           0.000008    1    0.6880    -8.370     0       0.0583  121.002
# 160           0.000000    0    0.0931    -4.771     1       0.0878  144.015
# 162           0.000000    0    0.2480    -6.476     1       0.0940  109.978
# 164           0.000000    3    0.1500    -7.621     0       0.1820  140.175
# ...                ...  ...       ...       ...   ...          ...      ...
# 4166          0.000000   10    0.2340    -5.087     1       0.1410   72.985
# 4168          0.000000    7    0.1120    -3.853     1       0.2720  107.952
# 4186          0.000179    6    0.1810    -4.410     0       0.0617  122.035
# 4200          0.000000    3    0.2710    -8.556     1       0.0688  149.919
# 4223          0.000685    7    0.0775    -6.114     1       0.0478  120.066
#
#       valence  popularity_over75
# 156     0.756                  1
# 158     0.412                  1
# 160     0.682                  1
# 162     0.485                  1
# 164     0.737                  1
# ...       ...                ...
# 4166    0.821                  1
# 4168    0.653                  1
# 4186    0.640                  1
# 4200    0.723                  1
# 4223    0.534                  1
#
# [512 rows x 14 columns]

# %%
#Set up Model
target = spotifydf["popularity_over75"]
target_names = ["not popular", "popular"]

# %%
data = spotifydf.drop("popularity_over75", axis=1)
feature_names = data.columns
data.head()
# Out:
#    acousticness  danceability  duration_s  energy  explicit  instrumentalness  \
# 0         0.881         0.644     313.093   0.212         0          0.000022
# 1         0.955         0.627     295.093   0.184         0          0.000162
# 2         0.888         0.581     183.440   0.331         0          0.000015
# 3         0.930         0.442     147.907   0.399         0          0.000499
# 4         0.949         0.570      64.173   0.176         0          0.000000
#
#    key  liveness  loudness  mode  speechiness    tempo  valence
# 0   11    0.7980   -14.118     1       0.0347  117.072    0.441
# 1    1    0.0986   -15.533     1       0.0450  115.864    0.299
# 2    6    0.1470   -14.087     1       0.2430   88.303    0.642
# 3    6    0.9120   -12.661     1       0.0780  121.662    0.554
# 4    6    0.1470   -22.676     0       0.2990  135.687    0.348

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2)

# %%
model = RandomForestClassifier(n_estimators=1000)
rf = model.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.8963911525029103

# %%
y_predicted = model.predict(X_test)

# %%
f1_score(y_test, y_predicted, average='macro')
# Out:
# 0.6216364689171867

# %%
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[751,   6],
#        [ 83,  19]], dtype=int64)

# %%
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.09805733105154318, 'loudness'),
#  (0.09733026169215475, 'duration_s'),
#  (0.09598743580478962, 'instrumentalness'),
#  (0.08991920854309524, 'danceability'),
#  (0.088475098637368, 'speechiness'),
#  (0.08816703731515758, 'acousticness'),
#  (0.08379533827335837, 'tempo'),
#  (0.08297305507369984, 'energy'),
#  (0.07653570312817604, 'liveness'),
#  (0.075024407758031, 'valence'),
#  (0.06782482544033637, 'explicit'),
#  (0.04510426585598729, 'key'),
#  (0.010806031426302726, 'mode')]

# %%
#Remove key and mode and re check model
data2 = spotifydf.drop(columns=['mode', 'key', 'popularity_over75'], axis=1)
feature_names = data2.columns
data2.head()
# Out:
#    acousticness  danceability  duration_s  energy  explicit  instrumentalness  \
# 0         0.881         0.644     313.093   0.212         0          0.000022
# 1         0.955         0.627     295.093   0.184         0          0.000162
# 2         0.888         0.581     183.440   0.331         0          0.000015
# 3         0.930         0.442     147.907   0.399         0          0.000499
# 4         0.949         0.570      64.173   0.176         0          0.000000
#
#    liveness  loudness  speechiness    tempo  valence
# 0    0.7980   -14.118       0.0347  117.072    0.441
# 1    0.0986   -15.533       0.0450  115.864    0.299
# 2    0.1470   -14.087       0.2430   88.303    0.642
# 3    0.9120   -12.661       0.0780  121.662    0.554
# 4    0.1470   -22.676       0.2990  135.687    0.348

# %%
X_train1, X_test1, y_train, y_test = train_test_split(data2, target, test_size=0.2, random_state = 1)

# %%
model2 = RandomForestClassifier(n_estimators=10)
rf = model2.fit(X_train1, y_train)
rf.score(X_test1, y_test)
# Out:
# 0.9068684516880093

# %%
y_predicted1 = model2.predict(X_test1)

# %%
f1_score(y_test, y_predicted1, average='macro')
# Out:
# 0.667118775431118

# %%
cm1 = confusion_matrix(y_test, y_predicted1)
cm1
# Out:
# array([[754,  12],
#        [ 68,  25]], dtype=int64)

# %%
plt.figure(figsize=(10,7))
sn.heatmap(cm1, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.14011078873611682, 'loudness'),
#  (0.13455758266387685, 'duration_s'),
#  (0.12892923314428334, 'acousticness'),
#  (0.1254267434822371, 'instrumentalness'),
#  (0.12419894813492278, 'danceability'),
#  (0.11964639159995863, 'speechiness'),
#  (0.11817574642932165, 'energy'),
#  (0.10895456580928282, 'tempo')]

# %%
model2.predict([])
