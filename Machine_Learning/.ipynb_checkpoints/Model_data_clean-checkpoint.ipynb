# %%
from sklearn import tree
import pandas as pd
import os

# %%
spotifydf = pd.read_csv('2020only_Clean_Spotify_Attribute_Data.csv')
spotifydf
# Out:
#                                                    name           artist  \
# 0     The Circle Game - Live at The 2nd Fret, Philad...  'Joni Mitchell'
# 1     Urge For Going - Live at The 2nd Fret, Philade...  'Joni Mitchell'
# 2     What's The Story Mr. Blue - Live at The 2nd Fr...  'Joni Mitchell'
# 3     Brandy Eyes - Live at The 2nd Fret, Philadelph...  'Joni Mitchell'
# 4     Intro To Urge For Going - Live at The 2nd Fret...  'Joni Mitchell'
# ...                                                 ...              ...
# 4289                          Only Tonight - Radio Edit      'Stephan F'
# 4290                                              LayUp   'BigBankCarti'
# 4291                                            The One       'DJ Combo'
# 4292                                           Together      'Roger Fly'
# 4293                                     Improvisations      'Roger Fly'
#
#       year  acousticness  danceability  duration_ms  energy  explicit  \
# ...
